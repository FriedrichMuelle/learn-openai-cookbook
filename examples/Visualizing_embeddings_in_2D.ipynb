# %% [markdown]
# ## Visualizing the embeddings in 2D
#
# We will use t-SNE to reduce the dimensionality of the embeddings from 1536 to 2. Once the embeddings are reduced to two dimensions, we can plot them in a 2D scatter plot. The dataset is created in the [Get_embeddings_from_dataset Notebook](Get_embeddings_from_dataset.ipynb).

# %% [markdown]
# ### 1. Reduce dimensionality
#
# We reduce the dimensionality to 2 dimensions using t-SNE decomposition.

# %%
# %pip install tiktoken openai pandas matplotlib plotly scikit-learn numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tiktoken
#   Downloading tiktoken-0.7.0-cp39-cp39-macosx_11_0_arm64.whl (907 kB)
#      |████████████████████████████████| 907 kB 663 kB/s eta 0:00:01
# Collecting openai
#   Downloading openai-1.29.0-py3-none-any.whl (320 kB)
#      |████████████████████████████████| 320 kB 10.2 MB/s eta 0:00:01
# Collecting pandas
#   Downloading pandas-2.2.2-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 586 kB/s eta 0:00:01
# Collecting matplotlib
#   Downloading matplotlib-3.8.4-cp39-cp39-macosx_11_0_arm64.whl (7.5 MB)
#      |████████████████████████████████| 7.5 MB 862 kB/s eta 0:00:01
# Collecting plotly
#   Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#      |████████████████████████████████| 16.4 MB 2.7 MB/s eta 0:00:01
# Collecting scikit-learn
#   Downloading scikit_learn-1.4.2-cp39-cp39-macosx_12_0_arm64.whl (10.5 MB)
#      |████████████████████████████████| 10.5 MB 2.8 MB/s eta 0:00:01
# Collecting numpy
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#      |████████████████████████████████| 14.0 MB 13.4 MB/s eta 0:00:01
# Collecting requests>=2.26.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.9 MB/s eta 0:00:01
# Collecting regex>=2022.1.18
#   Downloading regex-2024.5.10-cp39-cp39-macosx_11_0_arm64.whl (278 kB)
#      |████████████████████████████████| 278 kB 2.8 MB/s eta 0:00:01
# Collecting anyio<5,>=3.5.0
#   Downloading anyio-4.3.0-py3-none-any.whl (85 kB)
#      |████████████████████████████████| 85 kB 2.7 MB/s eta 0:00:01
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      |████████████████████████████████| 75 kB 2.5 MB/s eta 0:00:01
# Collecting pydantic<3,>=1.9.0
#   Downloading pydantic-2.7.1-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 2.4 MB/s eta 0:00:01
# Collecting sniffio
#   Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting distro<2,>=1.7.0
#   Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting tqdm>4
#   Downloading tqdm-4.66.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 2.5 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/prigogine/Library/Python/3.9/lib/python/site-packages (from openai) (4.11.0)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      |████████████████████████████████| 345 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/prigogine/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 2.6 MB/s eta 0:00:01
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.2.1-cp39-cp39-macosx_11_0_arm64.whl (244 kB)
#      |████████████████████████████████| 244 kB 2.2 MB/s eta 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.51.0-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
#      |████████████████████████████████| 2.8 MB 2.4 MB/s eta 0:00:01
# Collecting pillow>=8
#   Downloading pillow-10.3.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 2.9 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.1.2-py3-none-any.whl (103 kB)
#      |████████████████████████████████| 103 kB 7.0 MB/s eta 0:00:01
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.5-cp39-cp39-macosx_11_0_arm64.whl (66 kB)
#      |████████████████████████████████| 66 kB 6.7 MB/s eta 0:00:011
# Collecting importlib-resources>=3.2.0
#   Downloading importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/prigogine/Library/Python/3.9/lib/python/site-packages (from matplotlib) (24.0)
# Collecting tenacity>=6.2.0
#   Downloading tenacity-8.3.0-py3-none-any.whl (25 kB)
# Collecting scipy>=1.6.0
#   Downloading scipy-1.13.0-cp39-cp39-macosx_12_0_arm64.whl (30.3 MB)
#      |████████████████████████████████| 30.3 MB 2.7 MB/s eta 0:00:01     |█████████████████▌              | 16.6 MB 2.2 MB/s eta 0:00:07
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#      |████████████████████████████████| 301 kB 2.2 MB/s eta 0:00:01
# Collecting idna>=2.8
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/prigogine/Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 2.9 MB/s eta 0:00:01
# Collecting certifi
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 2.5 MB/s eta 0:00:01
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 2.7 MB/s eta 0:00:01
# Requirement already satisfied: zipp>=3.1.0 in /Users/prigogine/Library/Python/3.9/lib/python/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.18.1)
# Collecting pydantic-core==2.18.2
#   Downloading pydantic_core-2.18.2-cp39-cp39-macosx_11_0_arm64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 2.7 MB/s eta 0:00:01
# Collecting annotated-types>=0.4.0
#   Downloading annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp39-cp39-macosx_11_0_arm64.whl (120 kB)
#      |████████████████████████████████| 120 kB 2.6 MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      |████████████████████████████████| 121 kB 2.9 MB/s eta 0:00:01
# Installing collected packages: sniffio, idna, h11, certifi, urllib3, pydantic-core, numpy, httpcore, charset-normalizer, anyio, annotated-types, tzdata, tqdm, threadpoolctl, tenacity, scipy, requests, regex, pytz, pyparsing, pydantic, pillow, kiwisolver, joblib, importlib-resources, httpx, fonttools, distro, cycler, contourpy, tiktoken, scikit-learn, plotly, pandas, openai, matplotlib
# Successfully installed annotated-types-0.6.0 anyio-4.3.0 certifi-2024.2.2 charset-normalizer-3.3.2 contourpy-1.2.1 cycler-0.12.1 distro-1.9.0 fonttools-4.51.0 h11-0.14.0 httpcore-1.0.5 httpx-0.27.0 idna-3.7 importlib-resources-6.4.0 joblib-1.4.2 kiwisolver-1.4.5 matplotlib-3.8.4 numpy-1.26.4 openai-1.29.0 pandas-2.2.2 pillow-10.3.0 plotly-5.22.0 pydantic-2.7.1 pydantic-core-2.18.2 pyparsing-3.1.2 pytz-2024.1 regex-2024.5.10 requests-2.31.0 scikit-learn-1.4.2 scipy-1.13.0 sniffio-1.3.1 tenacity-8.3.0 threadpoolctl-3.5.0 tiktoken-0.7.0 tqdm-4.66.4 tzdata-2024.1 urllib3-2.2.1
# WARNING: You are using pip version 21.2.4; however, version 24.0 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.manifold import TSNE
import numpy as np
from ast import literal_eval

# Load the embeddings
datafile_path = "data/fine_food_reviews_with_embeddings_1k.csv"
df = pd.read_csv(datafile_path)

# Convert to a list of lists of floats
matrix = np.array(df.embedding.apply(literal_eval).to_list())

# Create a t-SNE model and transform the data
tsne = TSNE(n_components=2, perplexity=15, random_state=42, init='random', learning_rate=200)
vis_dims = tsne.fit_transform(matrix)
vis_dims.shape
# Out:
# (1000, 2)

# %% [markdown]
# ### 2. Plotting the embeddings
#
# We colour each review by its star rating, ranging from red to green.

# %% [markdown]
# We can observe a decent data separation even in the reduced 2 dimensions.

# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

colors = ["red", "darkorange", "gold", "turquoise", "darkgreen"]
x = [x for x,y in vis_dims]
y = [y for x,y in vis_dims]
color_indices = df.Score.values - 1

colormap = matplotlib.colors.ListedColormap(colors)
plt.scatter(x, y, c=color_indices, cmap=colormap, alpha=0.3)
for score in [0,1,2,3,4]:
    avg_x = np.array(x)[df.Score-1==score].mean()
    avg_y = np.array(y)[df.Score-1==score].mean()
    color = colors[score]
    plt.scatter(avg_x, avg_y, marker='x', color=color, s=100)

plt.title("Amazon ratings visualized in language using t-SNE")
# Out:
# Text(0.5, 1.0, 'Amazon ratings visualized in language using t-SNE')
